# %% [markdown]
# # CSC311 Lab 8: Naive Bayes for Classifying Movie Reviews
#
# In this lab, we will build a naive bayes model to classify positive vs
# negative movie reviews.
#
# By the end of this lab , you will be able to:
#
# 1. Use the "bag of word" representation of text.
# 2. Build naive bayes classifiers to solve classification problems.
# 3. Analyze MLE vs Bayesian parameter estimation methods.
# 4. Use a naive bayes classifier to make predictions.
#
# Please work in groups of 1-2 during the lab.
#
#
# ## Submission
#
# If you are working with a partner, start by creating a group on Markus. If you are working alone,
# click "Working Alone".
#
# Submit the ipynb file `lab07.ipynb` on Markus
# **containing all your solutions to the Graded Tasks**.
# Your notebook file must contain your code **and outputs** where applicable,
# including printed lines and images.
# Your TA will not run your code for the purpose of grading.
#
# For this lab, you should submit the following:
#
# - Part 1. your creation of the `vocab` list and report of the size of the vocabulary (1 point)
# - Part 1. your implementation of the `make_bow` function (1 point)
# - Part 2. your implementation of the `naive_bayes_mle` function (2 points)
# - Part 2. your implementation of the `naive_bayes_map` function (2 points)
# - Part 3. your implementation of the `make_prediction` function (3 points)
# - Part 3. your training/validation accuracy of a logistic regression model trained on this data (1 point)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Acknowledgements
#
# Data is a variation of the one from https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews,
# pre-processed so that only 1000 words are in the training/test set.
#
#
# ## Part 1. Data
#
# As before, we need to upload our data to Colab. This time, we have two separate files (dowloaded from Quercus), trainvalid.csv and test.csv.  To do this, click on the 'Files' button on the left sidebar (which looks like a folder). Then, click the 'Upload to session storage' button (which has an up-arrow) and upload trainvalid.csv and test.csv. Make sure that you are in the 'content' directory when you do this. (This is the default directory you start in.)
#
# As always, we start by understanding what our data looks like. Notice that the
# test set has been set aside for us. Both the training and test set files follow
# the same format, where each line in the csv file contains the review text and
# the string label "positive" or "negative".

# %%
import csv
trainfile = "trainvalid.csv"
testfile = "test.csv"

# Training/Validation set
data = csv.reader(open(trainfile))
for i, line in enumerate(data):
    print(line)
    if i > 10:
        break
# Out:
# ['im not sure i havent seen every episode but i still enjoyed it its hard to say which episode was my favorite', 'positive']
# ['this film has everything ask yourself are you a fan of and ive seen a lot of movies', 'positive']
# ['its not going to be the japanese version the show is great but', 'positive']
# ['i would love to see either of them in another movie', 'positive']
# ['this movie is great if you enjoy watching b class movies that is', 'positive']
# ['if you can do that it really is good s s s s i doubt it too bad', 'positive']
# ['this movie has some things that are pretty amazing first it is supposed to be based on a true story the problem was that by then you would be able to hear it', 'positive']
# ['first of all i want to point on screen play', 'positive']
# ['this is the best movie i have ever seen any movie that can get children to learn history is great', 'positive']
# ['lets start with the good things this is not a movie for kids the action scenes are great here too ok over to the things i didnt like thats that', 'positive']
# ['but it is still dont care is it worth try it', 'positive']
# ['while by no means a classic the directors involved do have an idea what suspense is', 'positive']

# %%
# Test set (separated so that we will all have the same test set)
data = csv.reader(open(testfile))
for i, line in enumerate(data):
    print(line)
    if i > 10:
        break
# Out:
# ['what a great film a great cast as well i really enjoy this movie', 'positive']
# ['i cant say enough about this movie sometimes it feels as if youre watching a real documentary', 'positive']
# ['it was probably the most black comedy ive seen i really do recommend it to you', 'positive']
# ['old movies new movies im not sure why i cant get a copy its about time for this to happen it doesnt seem like this should be so difficult', 'positive']
# ['that film is absolutely fantastic if you watch it with your friends it can be a very nice day', 'positive']
# ['one did not need it anyway she knows this man is different', 'positive']
# ['he was something never before seen he was all we ever needed', 'positive']
# ['lets take the second point first but it is only that moment all three white actors did the role in black face i heard different things about this so the film is definitely worth watching', 'positive']
# ['i also think this is one of the greatest movies of the last years', 'positive']
# ['a great movie the acting is basically above average nothing special but better then average', 'positive']
# ['if you get a chance watch this movie and it is family comedy entertainment at its best', 'positive']
# ['i remember watching this movie when it came out as a t they just dont make t all on one dvd movies like this', 'positive']

# %% [markdown]
# **Task**: How many positive reviews are in `trainvalid.csv`?  Negative reviews? What about in `test.csv`?

# %%
import csv
from collections import Counter

# Count trainvalid.csv
train_labels = [row[1] for row in csv.reader(open("trainvalid.csv"))]
train_counts = Counter(train_labels)
print("trainvalid.csv:")
print("  Positive:", train_counts["positive"])
print("  Negative:", train_counts["negative"])

# Count test.csv
test_labels = [row[1] for row in csv.reader(open("test.csv"))]
test_counts = Counter(test_labels)
print("test.csv:")
print("  Positive:", test_counts["positive"])
print("  Negative:", test_counts["negative"])
# Out:
# trainvalid.csv:
#   Positive: 6000
#   Negative: 6000
# test.csv:
#   Positive: 2000
#   Negative: 2000

# %% [markdown]
# **Graded Task**: How many unique words are in the entire training/validation set?
# This will be the size of our **vocabulary** when we convert to a bag-of-word representation.
# To compute this value, produce a list `vocab` that contains a list of unique words
# in `trainvalid.csv`.
#
# Splitting sentences into words is typically not a trivial operation. For this lab, punctuations
# and other special symbols have already been removed from the reviews. So, using python's
# `string.split()` method is sufficient.

# %%
vocab = list(set(word for row in data for word in row[0].split()))

print("Vocabulary Size: ", len(vocab)) # Please include the output of this statement in your submission
# Out:
# Vocabulary Size:  996

# %% [markdown]
# **Graded Task**: Complete the function `make_bow`, which takes a list of `(review, label)` pairs
# and a list of words in the vocabulary, and produces a data matrix consisting of bag-of-word features,
# along with a vector of labels.

# %%
def make_bow(data, vocab):
    """
    Produce the bag-of-word representation of the data, along with a vector
    of labels. You *may* use loops to iterate over `data`. However, your code
    should not take more than O(len(data) * len(vocab)) to run.

    Parameters:
        `data`: a list of `(review, label)` pairs, like those produced from
                `list(csv.reader(open("trainvalid.csv")))`
        `vocab`: a list consisting of all unique words in the vocabulary

    Returns:
        `X`: A data matrix of bag-of-word features. This data matrix should be
             a numpy array with shape [len(data), len(vocab)].
             Moreover, `X[i,j] == 1` if the review in `data[i]` contains the
             word `vocab[j]`, and `X[i,j] == 0` otherwise.
        `t`: A numpy array of shape [len(data)], with `t[i] == 1` if
             `data[i]` is a positive review, and `t[i] == 0` otherwise.
    """
    X = np.zeros([len(data), len(vocab)])
    t = np.zeros([len(data)])

    vocab_index = {word: j for j, word in enumerate(vocab)}  # O(V) lookup map

    for i, (review, label) in enumerate(data):
        t[i] = 1 if label == "positive" else 0
        for word in review.split():
            if word in vocab_index:
                X[i, vocab_index[word]] = 1

    return X, t

# Separate data into training/validation, then call `make_bow` to produce
# the bag-of-word features
import random
random.seed(42)
data = list(csv.reader(open(trainfile)))
random.shuffle(data)
X_train, t_train = make_bow(data[:10000], vocab)
X_valid, t_valid = make_bow(data[10000:], vocab)

# %% [markdown]
# **Task**: It is a good idea to understand the distribution of relative word occurrences.
# Produce the figure below, which shows how often each word occurs in the training set.

# %%
# produce the mapping of words to count
vocab_count_mapping = list(zip(vocab, np.sum(X_train, axis=0)))
vocab_count_mapping = sorted(vocab_count_mapping, key=lambda e: e[1], reverse=True)
for word, cnt in vocab_count_mapping:
    print(word, cnt)
# Out:
# the 6046.0
# this 5162.0
# i 4785.0
# it 4767.0
# a 4300.0
# is 4172.0
# to 3682.0
# movie 3567.0
# and 3366.0
# of 3152.0
# that 2588.0
# was 2446.0
# not 2244.0
# but 2218.0
# in 2097.0
# you 2043.0
# film 1951.0
# have 1602.0
# good 1558.0
# one 1505.0
# for 1472.0
# what 1464.0
# its 1460.0
# all 1424.0
# so 1302.0
# just 1281.0
# be 1190.0
# really 1132.0
# see 1068.0
# like 1043.0
# bad 1029.0
# if 1014.0
# dont 1005.0
# there 1004.0
# on 1001.0
# are 998.0
# about 983.0
# they 932.0
# well 928.0
# time 907.0
# very 890.0
# as 889.0
# at 888.0
# with 863.0
# great 847.0
# seen 837.0
# do 808.0
# watch 780.0
# no 778.0
# would 693.0
# can 693.0
# acting 691.0
# my 691.0
# know 688.0
# think 686.0
# much 684.0
# me 682.0
# ever 681.0
# more 673.0
# story 665.0
# out 652.0
# movies 641.0
# say 634.0
# how 630.0
# even 619.0
# get 617.0
# he 612.0
# did 588.0
# has 569.0
# or 563.0
# could 563.0
# why 558.0
# will 538.0
# love 531.0
# thats 529.0
# better 520.0
# some 516.0
# too 514.0
# made 511.0
# were 505.0
# first 504.0
# funny 481.0
# worst 472.0
# had 470.0
# then 469.0
# didnt 454.0
# we 449.0
# make 447.0
# never 433.0
# people 431.0
# best 429.0
# when 426.0
# an 425.0
# nothing 418.0
# way 417.0
# from 413.0
# who 412.0
# been 409.0
# than 399.0
# thing 394.0
# only 390.0
# plot 388.0
# watching 385.0
# your 381.0
# go 375.0
# still 372.0
# end 369.0
# she 369.0
# again 368.0
# actors 368.0
# them 358.0
# now 356.0
# show 355.0
# because 354.0
# recommend 354.0
# ive 353.0
# cant 346.0
# should 345.0
# does 342.0
# im 338.0
# isnt 332.0
# want 329.0
# worth 329.0
# thought 329.0
# other 322.0
# lot 320.0
# any 316.0
# here 311.0
# by 310.0
# something 306.0
# waste 301.0
# characters 300.0
# where 298.0
# many 296.0
# doesnt 296.0
# going 295.0
# sure 292.0
# also 292.0
# most 286.0
# pretty 284.0
# films 281.0
# wrong 280.0
# up 277.0
# done 275.0
# fun 275.0
# his 273.0
# cast 273.0
# actually 266.0
# makes 265.0
# her 265.0
# work 265.0
# enjoy 264.0
# real 260.0
# life 260.0
# little 257.0
# got 250.0
# loved 249.0
# terrible 249.0
# right 247.0
# horror 242.0
# though 240.0
# look 238.0
# believe 237.0
# wasnt 237.0
# give 233.0
# saw 233.0
# things 232.0
# anything 232.0
# interesting 230.0
# awful 230.0
# must 229.0
# after 228.0
# oh 226.0
# over 223.0
# him 223.0
# find 221.0
# script 221.0
# money 217.0
# ending 217.0
# mr 215.0
# come 215.0
# watched 215.0
# least 212.0
# liked 211.0
# point 210.0
# maybe 210.0
# said 210.0
# anyone 209.0
# enough 207.0
# quite 207.0
# those 205.0
# which 203.0
# far 201.0
# comedy 201.0
# boring 201.0
# these 201.0
# else 200.0
# everything 199.0
# whole 198.0
# however 195.0
# theres 195.0
# music 195.0
# sense 194.0
# times 193.0
# everyone 192.0
# stupid 192.0
# every 191.0
# back 191.0
# tv 191.0
# two 190.0
# same 190.0
# long 188.0
# action 188.0
# definitely 187.0
# hard 187.0
# scenes 187.0
# feel 187.0
# tell 186.0
# excellent 185.0
# laugh 184.0
# probably 180.0
# few 179.0
# before 179.0
# part 177.0
# character 176.0
# their 176.0
# mean 176.0
# horrible 175.0
# worse 174.0
# enjoyed 172.0
# yes 172.0
# absolutely 170.0
# am 169.0
# special 168.0
# disappointed 168.0
# series 167.0
# take 166.0
# overall 165.0
# original 165.0
# idea 163.0
# kind 163.0
# effects 161.0
# book 158.0
# dvd 155.0
# understand 155.0
# s 155.0
# such 154.0
# read 154.0
# either 153.0
# please 152.0
# rest 152.0
# hope 151.0
# big 151.0
# guess 150.0
# let 150.0
# perfect 150.0
# ok 147.0
# man 147.0
# thinking 145.0
# off 145.0
# scene 144.0
# always 143.0
# true 142.0
# another 141.0
# may 139.0
# seeing 138.0
# away 138.0
# nice 138.0
# reason 138.0
# different 138.0
# care 137.0
# couldnt 137.0
# chance 136.0
# problem 135.0
# wont 135.0
# into 135.0
# youll 134.0
# course 134.0
# need 134.0
# looking 133.0
# once 133.0
# anyway 133.0
# second 133.0
# fact 132.0
# wonderful 132.0
# years 132.0
# last 132.0
# seriously 132.0
# happen 131.0
# simply 130.0
# remember 130.0
# amazing 129.0
# wait 129.0
# supposed 128.0
# entertaining 127.0
# might 127.0
# wanted 126.0
# okay 125.0
# budget 125.0
# truly 124.0
# director 124.0
# happens 123.0
# hes 121.0
# sad 121.0
# low 120.0
# through 120.0
# being 119.0
# classic 118.0
# beautiful 118.0
# sorry 117.0
# expect 116.0
# job 116.0
# kids 116.0
# half 116.0
# scary 116.0
# havent 115.0
# down 114.0
# predictable 113.0
# goes 113.0
# family 113.0
# favorite 113.0
# fan 112.0
# start 112.0
# id 112.0
# youre 112.0
# own 111.0
# found 110.0
# new 110.0
# try 109.0
# writing 109.0
# without 109.0
# almost 108.0
# crap 108.0
# mind 107.0
# making 107.0
# short 106.0
# lets 106.0
# hate 105.0
# poor 105.0
# gets 105.0
# happened 104.0
# day 104.0
# bit 104.0
# ill 104.0
# put 102.0
# rent 102.0
# knew 101.0
# went 101.0
# buy 101.0
# wish 100.0
# whats 100.0
# actor 99.0
# brilliant 99.0
# guy 99.0
# place 99.0
# since 98.0
# while 98.0
# cool 98.0
# yet 97.0
# old 97.0
# parts 97.0
# heard 97.0
# shows 96.0
# direction 96.0
# hell 95.0
# unfortunately 94.0
# us 93.0
# comes 93.0
# next 93.0
# stuff 93.0
# miss 93.0
# god 93.0
# someone 93.0
# main 93.0
# highly 92.0
# itself 92.0
# wouldnt 92.0
# world 92.0
# hilarious 92.0
# case 91.0
# video 91.0
# performances 91.0
# shame 91.0
# friends 91.0
# beginning 91.0
# surprised 91.0
# three 90.0
# came 90.0
# matter 90.0
# each 90.0
# written 89.0
# opinion 89.0
# ask 88.0
# saying 88.0
# wonder 88.0
# entire 88.0
# enjoyable 87.0
# fantastic 86.0
# already 85.0
# exactly 85.0
# seems 84.0
# keep 84.0
# yourself 84.0
# certainly 84.0
# b 84.0
# simple 83.0
# hour 83.0
# expected 83.0
# episode 82.0
# both 82.0
# screen 82.0
# works 81.0
# fine 81.0
# shot 80.0
# year 80.0
# stop 80.0
# felt 79.0
# night 79.0
# none 79.0
# forget 79.0
# until 79.0
# serious 79.0
# although 78.0
# drama 78.0
# doubt 77.0
# play 77.0
# told 77.0
# alone 77.0
# looks 76.0
# others 76.0
# trying 76.0
# surprise 76.0
# check 76.0
# seem 76.0
# stay 76.0
# dr 75.0
# home 75.0
# happy 74.0
# save 74.0
# guys 74.0
# decent 74.0
# together 74.0
# top 73.0
# shes 72.0
# joke 72.0
# knows 72.0
# soundtrack 72.0
# ten 71.0
# around 71.0
# t 71.0
# lines 71.0
# humor 71.0
# completely 71.0
# left 71.0
# talk 70.0
# girl 70.0
# ridiculous 69.0
# boy 69.0
# moments 69.0
# theyre 69.0
# close 69.0
# sound 69.0
# believable 68.0
# lost 67.0
# directing 67.0
# line 67.0
# jokes 66.0
# fans 66.0
# cinematography 66.0
# sex 66.0
# sequel 65.0
# perhaps 65.0
# possibly 65.0
# dialogue 65.0
# started 65.0
# picture 65.0
# avoid 65.0
# flick 65.0
# myself 65.0
# live 64.0
# performance 64.0
# help 64.0
# slow 64.0
# act 64.0
# problems 63.0
# getting 63.0
# finally 63.0
# realistic 62.0
# less 62.0
# begin 62.0
# seemed 62.0
# etc 62.0
# based 62.0
# young 61.0
# dead 61.0
# documentary 61.0
# gore 61.0
# forward 61.0
# especially 60.0
# hollywood 60.0
# looked 60.0
# title 60.0
# high 59.0
# person 59.0
# minutes 59.0
# word 59.0
# role 59.0
# name 59.0
# often 59.0
# review 58.0
# experience 58.0
# moment 58.0
# several 58.0
# genre 58.0
# says 58.0
# stars 58.0
# storyline 58.0
# ones 57.0
# lame 57.0
# superb 57.0
# dumb 57.0
# lots 57.0
# played 57.0
# annoying 57.0
# write 57.0
# game 57.0
# easy 57.0
# used 56.0
# quality 56.0
# laughs 56.0
# sit 56.0
# coming 56.0
# hours 56.0
# silly 56.0
# rather 56.0
# turn 55.0
# kid 55.0
# friend 55.0
# camera 55.0
# cannot 55.0
# sometimes 55.0
# average 54.0
# takes 54.0
# doing 54.0
# able 54.0
# die 54.0
# figure 54.0
# art 54.0
# totally 53.0
# comments 53.0
# piece 53.0
# version 52.0
# worked 52.0
# question 52.0
# feeling 52.0
# expecting 52.0
# change 51.0
# masterpiece 51.0
# theater 51.0
# possible 51.0
# talent 51.0
# call 51.0
# weak 51.0
# meant 51.0
# later 51.0
# given 50.0
# child 50.0
# having 50.0
# mess 50.0
# our 50.0
# extremely 50.0
# sort 50.0
# leave 50.0
# kill 49.0
# thriller 49.0
# stories 49.0
# days 49.0
# whatever 49.0
# couple 49.0
# admit 49.0
# development 49.0
# moving 48.0
# comment 48.0
# editing 48.0
# school 48.0
# follow 48.0
# youve 48.0
# pay 48.0
# important 48.0
# songs 48.0
# women 48.0
# wasted 47.0
# cheap 47.0
# killed 47.0
# arent 47.0
# reviews 47.0
# dull 47.0
# history 46.0
# mention 46.0
# suspense 46.0
# message 46.0
# tried 46.0
# soon 46.0
# type 45.0
# animation 45.0
# copy 45.0
# except 45.0
# learn 45.0
# crazy 45.0
# basically 45.0
# needed 45.0
# kept 45.0
# words 45.0
# hear 45.0
# gave 45.0
# run 44.0
# rate 44.0
# reading 44.0
# turned 44.0
# released 44.0
# memorable 44.0
# single 44.0
# star 44.0
# badly 44.0
# today 44.0
# greatest 43.0
# straight 43.0
# points 43.0
# cinema 43.0
# view 43.0
# eyes 43.0
# children 43.0
# involved 42.0
# needs 42.0
# imagine 42.0
# strange 42.0
# ends 42.0
# move 42.0
# example 42.0
# entertainment 42.0
# stand 42.0
# premise 42.0
# five 41.0
# talking 41.0
# men 41.0
# sci 41.0
# fi 41.0
# complete 41.0
# obviously 41.0
# means 41.0
# sounds 41.0
# acted 41.0
# beyond 41.0
# dialog 41.0
# strong 41.0
# took 41.0
# otherwise 41.0
# along 41.0
# reality 40.0
# black 40.0
# effort 40.0
# score 40.0
# roles 40.0
# wants 40.0
# instead 39.0
# production 39.0
# lives 39.0
# starts 39.0
# television 39.0
# song 39.0
# cheesy 39.0
# add 39.0
# obvious 39.0
# indeed 38.0
# taken 38.0
# shown 38.0
# ways 38.0
# wife 38.0
# difficult 38.0
# break 38.0
# late 37.0
# use 37.0
# face 37.0
# set 37.0
# audience 37.0
# house 37.0
# hit 37.0
# rating 36.0
# incredibly 36.0
# style 36.0
# open 36.0
# girls 36.0
# apparently 36.0
# actress 36.0
# lack 36.0
# truth 36.0
# woman 36.0
# dark 35.0
# episodes 35.0
# romantic 35.0
# imdb 35.0
# plenty 35.0
# death 35.0
# period 35.0
# cut 35.0
# gives 35.0
# unique 35.0
# viewing 35.0
# heart 35.0
# mystery 35.0
# small 34.0
# list 34.0
# fight 34.0
# attention 34.0
# clear 34.0
# weird 34.0
# level 34.0
# behind 34.0
# writer 34.0
# final 34.0
# credits 34.0
# voice 34.0
# four 34.0
# throughout 34.0
# war 33.0
# total 33.0
# future 33.0
# gone 33.0
# poorly 32.0
# musical 32.0
# evil 32.0
# full 32.0
# writers 32.0
# head 32.0
# spent 32.0
# between 32.0
# leads 32.0
# huge 32.0
# plus 31.0
# interest 31.0
# bring 31.0
# opening 31.0
# deserves 31.0
# deal 31.0
# parents 31.0
# become 31.0
# twist 31.0
# mother 31.0
# realize 31.0
# decided 30.0
# telling 30.0
# particularly 30.0
# plays 30.0
# sets 30.0
# playing 30.0
# american 30.0
# subject 30.0
# past 29.0
# cover 29.0
# third 29.0
# actual 29.0
# note 29.0
# side 29.0
# somewhat 29.0
# novel 29.0
# screenplay 29.0
# blood 29.0
# romance 29.0
# dream 29.0
# zombie 28.0
# living 28.0
# material 28.0
# above 28.0
# deep 28.0
# lead 28.0
# known 27.0
# whether 27.0
# feels 27.0
# supporting 27.0
# fast 27.0
# himself 27.0
# during 27.0
# easily 27.0
# number 27.0
# interested 27.0
# fairly 27.0
# violence 27.0
# usually 27.0
# apart 27.0
# directed 27.0
# tries 27.0
# keeps 27.0
# theme 27.0
# human 27.0
# minute 26.0
# atmosphere 26.0
# typical 26.0
# usual 26.0
# ago 26.0
# fall 26.0
# british 26.0
# mostly 26.0
# despite 26.0
# creepy 26.0
# dog 25.0
# whos 25.0
# giving 25.0
# father 25.0
# release 25.0
# age 25.0
# turns 25.0
# called 25.0
# boys 25.0
# season 24.0
# filmed 24.0
# similar 24.0
# taking 24.0
# dramatic 23.0
# directors 23.0
# falls 23.0
# earth 23.0
# free 23.0
# viewers 23.0
# major 23.0
# clearly 23.0
# older 22.0
# near 22.0
# elements 22.0
# class 22.0
# forced 22.0
# town 22.0
# fighting 22.0
# daughter 22.0
# light 21.0
# stage 21.0
# nearly 21.0
# middle 21.0
# western 21.0
# running 21.0
# hero 21.0
# son 21.0
# working 21.0
# ideas 21.0
# killer 21.0
# sequence 21.0
# power 21.0
# fails 21.0
# white 21.0
# husband 20.0
# powerful 20.0
# room 20.0
# somehow 20.0
# present 20.0
# general 20.0
# situation 20.0
# hot 20.0
# tells 19.0
# inside 19.0
# modern 19.0
# perfectly 19.0
# nor 19.0
# personal 19.0
# features 19.0
# themselves 19.0
# background 19.0
# begins 19.0
# result 19.0
# re 19.0
# english 19.0
# hand 19.0
# leaves 19.0
# murder 18.0
# relationship 18.0
# monster 18.0
# career 18.0
# across 18.0
# non 18.0
# bunch 18.0
# box 18.0
# party 18.0
# eventually 18.0
# meet 18.0
# girlfriend 18.0
# effect 18.0
# unless 18.0
# crime 18.0
# rock 18.0
# certain 17.0
# viewer 17.0
# hands 17.0
# particular 17.0
# car 17.0
# sequences 16.0
# brings 16.0
# setting 16.0
# appear 16.0
# french 16.0
# gay 16.0
# female 16.0
# shots 16.0
# team 16.0
# city 15.0
# gun 15.0
# oscar 15.0
# comic 15.0
# rich 15.0
# dance 15.0
# became 15.0
# feature 15.0
# earlier 15.0
# battle 15.0
# front 15.0
# lady 14.0
# police 14.0
# brother 14.0
# appears 14.0
# sister 14.0
# mark 14.0
# political 13.0
# fire 13.0
# beauty 13.0
# among 13.0
# due 13.0
# brought 13.0
# body 13.0
# york 13.0
# country 13.0
# portrayed 13.0
# crew 12.0
# quickly 12.0
# doctor 12.0
# space 12.0
# events 12.0
# under 12.0
# tale 12.0
# attempt 12.0
# upon 12.0
# nature 12.0
# form 12.0
# island 12.0
# order 11.0
# herself 11.0
# japanese 11.0
# finds 11.0
# water 11.0
# air 11.0
# following 11.0
# early 11.0
# famous 11.0
# within 11.0
# including 11.0
# emotional 11.0
# success 10.0
# becomes 10.0
# against 10.0
# meets 10.0
# group 10.0
# killing 10.0
# outside 10.0
# john 10.0
# leading 10.0
# america 9.0
# showing 9.0
# eye 9.0
# cop 9.0
# red 8.0
# business 8.0
# create 8.0
# attempts 8.0
# using 8.0
# era 8.0
# male 7.0
# various 7.0
# michael 7.0
# baby 7.0
# footage 6.0
# bill 6.0
# lee 6.0
# towards 6.0
# self 6.0
# david 6.0
# whose 6.0
# whom 6.0
# paul 5.0
# society 5.0
# previous 5.0
# jack 4.0
# named 3.0
# sexual 3.0
# james 3.0
# robert 3.0
# street 3.0
# peter 2.0
# richard 2.0
# george 2.0
# king 2.0

# %% [markdown]
# If we plot these occurrences, we see that the more common words tend to occur much more frequently
# compared to the less common words. This type of distribution occurs quite often in
# typical data sets, where there are a **long tail** of words that occur infrequently.

# %%
plt.plot([cnt for word, cnt in vocab_count_mapping])
plt.title("Distribution of words in the training data")
plt.xlabel("Word ranking (1=most common, 1000=least common)")
plt.ylabel("Number of occurrences")
# Out:
# Text(0, 0.5, 'Number of occurrences')

# %% [markdown]
# ## Part 2. Naive Bayes Model
#
# In this section, we will build a naive bayes model to predict whether a movie review
# is positive or negative. The naive bayes model is a generative model and a probabilistic classifier,
# where we will make the **conditional independence assumption**:
# $$p(c, x_1, \ldots, x_D) = p(c) p(x_1 | c) \cdots p(x_D | c)$$
#
# Where $c$ is the label class  (positive or negative), and each $x_j \in {0, 1}$ represents whether
# word $j$ appears in the review. We will fit parameters $\pi$ and $\theta_{jc}$, with:
#
# - $p(c=1) = \pi$, representing the probability of positive class
# - $p(x_j = 1 | c) = \theta_{jc}$, representing the probability of word $j$ appearing in a review with class $c$.
#
# **Graded Task**: Implement the function `naive_bayes_mle` that computes the MLE estimation of
# parameters. This function will produce the estimates of $\pi$ and the $\theta_{jc}$s that optimizes
# the log likelihood of the training data:
#
# $$\ell(\theta) = \sum_{i=1}^N \log p(c^{(i)}, {\bf x}^{(i)})$$
#
# Like mentioned in class, this formula sounds scary, but the estimates of $\pi$ and $\theta_{jc}$ turns out
# to require only basic counting operations and division.
# As such, we can implement this function in an entirely vectorized way, **without using loops**.
# Please do not use any loops in your solution.

# %%
def naive_bayes_mle(X, t):
    """
    Compute the parameters $pi$ and $theta_{jc}$ that maximizes the log-likelihood
    of the provided data (X, t).

    **Your solution should be vectorized, and contain no loops**

    Parameters:
        `X` - a matrix of bag-of-word features of shape [N, V],
              where N is the number of data points and V is the vocabulary size.
              X[i,j] should be either 0 or 1. Produced by the make_bow() function.
        `t` - a vector of class labels of shape [N], with t[i] being either 0 or 1.
              Produced by the make_bow() function.

    Returns:
        `pi` - a scalar; the MLE estimate of the parameter $\pi = p(c = 1)$
        `theta` - a matrix of shape [V, 2], where `theta[j, c]` corresponds to
                  the MLE estimate of the parameter $\theta_{jc} = p(x_j = 1 | c)$
    """
    N, vocab_size = X.shape[0], X.shape[1]

    X_positive = X[t == 1]
    X_negative = X[t == 0]

    pi = X_positive.shape[0] / N

    theta = np.zeros([vocab_size, 2])
    theta[:, 1] = X_positive.sum(axis=0) / X_positive.shape[0]
    theta[:, 0] = X_negative.sum(axis=0) / X_negative.shape[0]

    return pi, theta

pi_mle, theta_mle = naive_bayes_mle(X_train, t_train)
print(theta_mle.shape)
# Out:
# (996, 2)
# <>:16: SyntaxWarning: invalid escape sequence '\p'
# <>:16: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_265/3005180105.py:16: SyntaxWarning: invalid escape sequence '\p'
#   `pi` - a scalar; the MLE estimate of the parameter $\pi = p(c = 1)$

# %% [markdown]
# **Graded Task**: Implement the function `naive_bayes_map` that computes the MAP estimation of
# parameters. This function will produce the estimates of $\pi$ and the $\theta_{jc}$s that maximizes
# the posterior: $p(\theta | \mathcal{D})$, where $\theta = {\pi, \theta_{jc}}$ consists of all
# of our parameters.
#
# We will use the beta distribution with $a=2$ and $b=2$ for all of our parameters.
#
# Once again, although these words might sound scary, the estimates of $\pi$ and $\theta_{jc}$ turns out
# to require only basic counting operations and division---and not much more than the previous part!
# Again, we can implement this function in an entirely vectorized way, **without using loops**.
# Please do not use any loops in your solution.

# %%
def naive_bayes_map(X, t):
    """
    Compute the parameters $pi$ and $theta_{jc}$ that maximizes the posterior
    of the provided data (X, t). We will use the beta distribution with
    $a=2$ and $b=2$ for all of our parameters.

    **Your solution should be vectorized, and contain no loops**

    Parameters:
        `X` - a matrix of bag-of-word features of shape [N, V],
              where N is the number of data points and V is the vocabulary size.
              X[i,j] should be either 0 or 1. Produced by the make_bow() function.
        `t` - a vector of class labels of shape [N], with t[i] being either 0 or 1.
              Produced by the make_bow() function.

    Returns:
        `pi` - a scalar; the MAP estimate of the parameter $\pi = p(c = 1)$
        `theta` - a matrix of shape [V, 2], where `theta[j, c]` corresponds to
                  the MAP estimate of the parameter $\theta_{jc} = p(x_j = 1 | c)$
    """
    a, b = 2, 2  # Beta prior hyperparameters

    X_positive = X[t == 1]
    X_negative = X[t == 0]

    N_pos = X_positive.shape[0]
    N_neg = X_negative.shape[0]
    N = N_pos + N_neg

    # MAP estimate for pi: (count_positive + a - 1) / (N + a + b - 2)
    pi = (N_pos + a - 1) / (N + a + b - 2)

    theta = np.zeros([X.shape[1], 2])
    theta[:, 1] = (X_positive.sum(axis=0) + a - 1) / (N_pos + a + b - 2)
    theta[:, 0] = (X_negative.sum(axis=0) + a - 1) / (N_neg + a + b - 2)

    return pi, theta

pi_map, theta_map = naive_bayes_map(X_train, t_train)
print(theta_map.shape)
# Out:
# (996, 2)
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# <>:17: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_265/2335516726.py:17: SyntaxWarning: invalid escape sequence '\p'
#   `pi` - a scalar; the MAP estimate of the parameter $\pi = p(c = 1)$

# %% [markdown]
# ## Part 3. Making predictions
#
# **Graded Task**: Complete the function `make_prediction` which uses our estimated parameters $\pi$ and $\theta_{jc}$ to make predictions on our dataset.
#
# Note that computing products of many small numbers leads to underflow. Use the fact that:
#
# $$a_1 \cdot a_2 \cdots a_n = e^{log(a_1) + log(a_2) + \cdots + log(a_n)} $$
#
# to avoid computing a product of small numbers.

# %%
def make_prediction(X, pi, theta):
    # Log-likelihood of each class for every data point
    # log p(c=1) + sum_j [ x_j*log(theta_j1) + (1-x_j)*log(1-theta_j1) ]
    log_pos = (np.log(pi)
               + X @ np.log(theta[:, 1])
               + (1 - X) @ np.log(1 - theta[:, 1]))  # shape [N]

    log_neg = (np.log(1 - pi)
               + X @ np.log(theta[:, 0])
               + (1 - X) @ np.log(1 - theta[:, 0]))  # shape [N]

    y = (log_pos > log_neg).astype(int)
    return y

def accuracy(y, t):
    return np.mean(y == t)

y_map_train = make_prediction(X_train, pi_map, theta_map)
y_map_valid = make_prediction(X_valid, pi_map, theta_map)

print("MAP Train Acc:", accuracy(y_map_train, t_train))
print("MAP Valid Acc:", accuracy(y_map_valid, t_valid))
# Out:
# MAP Train Acc: 0.7879
# MAP Valid Acc: 0.785

# %% [markdown]
# At this point, you might wonder if the accuracy is "about right", and you might
# ask your instructors/TAs about what the expected accuracy might be.
# But what can we do to verify our results in real applications? One strategy
# is to compare your model output with other known models.
#
# **Graded Task**: Use sklearn to build a logistic regression model.
# Report the training and validation accuracy.
# You should see that the Logistic Regression model performs a bit better
# than the Naive Bayes model. The Logistic Regression model does not make
# as many assumptions about the data distribution that the Naive Bayes does.
# (Think: what are these assumptions?)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, t_train)

train_acc = lr.score(X_train, t_train)
val_acc = lr.score(X_valid, t_valid)

print("LR Train Acc:", train_acc)
print("LR Valid Acc:", val_acc)
# Out:
# LR Train Acc: 0.8247
# LR Valid Acc: 0.7865

# %% [markdown]
# This task is also a reminder that the bag of word features we built
# are just *features*, and can be used with *any* model!
#
# **Task**: The below code produces a warning or an error. Why?

# %%
y_mle_train = make_prediction(X_train, pi_mle, theta_mle)
y_mle_valid = make_prediction(X_valid, pi_mle, theta_mle)
print("MLE Train Acc:", accuracy(y_mle_train, t_train))
print("MLE Valid Acc:", accuracy(y_mle_valid, t_valid))
# Out:
# MLE Train Acc: 0.5007
# MLE Valid Acc: 0.4965
# /tmp/ipykernel_265/1272306553.py:5: RuntimeWarning: divide by zero encountered in log
#   + X @ np.log(theta[:, 1])
# /tmp/ipykernel_265/1272306553.py:5: RuntimeWarning: invalid value encountered in matmul
#   + X @ np.log(theta[:, 1])
# /tmp/ipykernel_265/1272306553.py:9: RuntimeWarning: divide by zero encountered in log
#   + X @ np.log(theta[:, 0])
# /tmp/ipykernel_265/1272306553.py:9: RuntimeWarning: invalid value encountered in matmul
#   + X @ np.log(theta[:, 0])

# %%
# The MLE model produces a warning because some words never appear in one of the classes in the training set, giving theta[j, c] = 0/N = 0.
# Computing log(0) = -inf causes "divide by zero" warnings, and when both classes have -inf log-likelihood for a word, (-inf) - (-inf) = nan,
# making predictions undefined -> hence the ~50% (random) accuracy.

# MAP fixes this by adding Beta prior pseudocounts, ensuring no theta is ever exactly 0, so log(theta) is always finite.

# %% [markdown]
# **Task**: The function `predict` is written for you, and provides another way to
# interact with the Naive Bayes model. The function takes a review (as a string),
# and relevant information about the naive bayes model, and produce an estimate
# for that single string.
#
# Call `predict` several times, with short reviews that you write, to get a sense
# of how the model behaves.

# %%
def predict(review, vocab, pi, theta):
    x = np.zeros([1, len(vocab)])
    words = review.split()
    for j, w in enumerate(vocab):
        if w in words:
            x[0, j] = 1
    return make_prediction(x, pi, theta)[0]

predict("movie was fun", vocab, pi_map, theta_map)
# Out:
# np.int64(1)

# %% [markdown]
# **Task**: Explain why the MLE model fails to make predictions (or produces a warning) for a review
# with the word "william" in it.

# %%
print(predict("william", vocab, pi_map, theta_map)) # why does this succeed
print(predict("william", vocab, pi_mle, theta_mle)) # ...and this produce an error?

# "william" appears in only one class (positive or negative) in the training set, so MLE estimates theta["william", c] = 0 for the class it never appears in.
# This causes log(0) = -inf in make_prediction, and since both log_pos and log_neg become -inf, the comparison -inf > -inf is undefined (nan), breaking
# the prediction. MAP avoids this by adding Beta(2,2) pseudocounts, so theta is always > 0.
# Out:
# 1
# 0
# /tmp/ipykernel_265/1272306553.py:5: RuntimeWarning: divide by zero encountered in log
#   + X @ np.log(theta[:, 1])
# /tmp/ipykernel_265/1272306553.py:5: RuntimeWarning: invalid value encountered in matmul
#   + X @ np.log(theta[:, 1])
# /tmp/ipykernel_265/1272306553.py:9: RuntimeWarning: divide by zero encountered in log
#   + X @ np.log(theta[:, 0])
# /tmp/ipykernel_265/1272306553.py:9: RuntimeWarning: invalid value encountered in matmul
#   + X @ np.log(theta[:, 0])

# %% [markdown]
# **Task**: Report the test accuracy on the naive bayes model with parameter estimation via MAP.

# %%
X_test, t_test = make_bow(list(csv.reader(open(testfile))), vocab)
y_map_test = make_prediction(X_test, pi_map, theta_map)
print("MAP Test Acc:", accuracy(y_map_test, t_test))
# Out:
# MAP Test Acc: 0.7515

# %% [markdown]
# ## Part 4. Analyzing the MAP Parameters
#
# **Task**: Write code to print the following:
#
# - the 10 words whose *presence* most strongly predicts that the review is positive
# - the 10 words whose *absense* most strongly predicts that the review is positive
# - the 10 words whose *presence* most strongly predicts that the review is negative
# - the 10 words whose *absense* most strongly predicts that the review is negative
#
# Note that these require more than just sorting the $\theta_{jc}$s! (Why?)

# %%
vocab = np.array(vocab)

# Log-odds contribution of each word being present or absent
log_odds_present = np.log(theta_map[:, 1]) - np.log(theta_map[:, 0])
log_odds_absent  = np.log(1 - theta_map[:, 1]) - np.log(1 - theta_map[:, 0])

top10 = 10

# Presence/absence most strongly predicts POSITIVE (highest log-odds)
print("Top 10 words whose PRESENCE predicts positive:")
print(vocab[np.argsort(log_odds_present)[-top10:][::-1]])

print("\nTop 10 words whose ABSENCE predicts positive:")
print(vocab[np.argsort(log_odds_absent)[-top10:][::-1]])

# Presence/absence most strongly predicts NEGATIVE (lowest log-odds)
print("\nTop 10 words whose PRESENCE predicts negative:")
print(vocab[np.argsort(log_odds_present)[:top10]])

print("\nTop 10 words whose ABSENCE predicts negative:")
print(vocab[np.argsort(log_odds_absent)[:top10]])
# Out:
# Top 10 words whose PRESENCE predicts positive:
# ['amazing' 'superb' 'loved' 'favorite' 'excellent' 'highly' 'greatest'
#  'wonderful' 'paul' 'perfectly']
#
# Top 10 words whose ABSENCE predicts positive:
# ['bad' 'the' 'worst' 'not' 'was' 'this' 'just' 'no' 'waste' 'dont']
#
# Top 10 words whose PRESENCE predicts negative:
# ['waste' 'worst' 'awful' 'avoid' 'poor' 'annoying' 'terrible' 'horrible'
#  'attempts' 'wasted']
#
# Top 10 words whose ABSENCE predicts negative:
# ['great' 'a' 'and' 'see' 'love' 'you' 'best' 'it' 'loved' 'film']

# %%
# We can't just sort theta[j, c] because a word with high theta[j, 1] might also have high theta[j, 0], meaning it appears often in BOTH classes and
# is not discriminative. What matters is the log-odds ratio:

# Presence: log(theta[j,1]) - log(theta[j,0])
#   → how much more likely the word APPEARS in positive vs negative reviews

# Absence: log(1 - theta[j,1]) - log(1 - theta[j,0])
#   → how much more likely the word is MISSING in positive vs negative reviews
